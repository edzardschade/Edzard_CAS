# %% [markdown]
# Zusammenführen diverser FB-Daten in eine Tabelle

# %%
import pandas as pd

# %%
import numpy as np

# %%
import glob

# %%
import re

# %%
path = 'facebookdaten/'

# %% [markdown]
# Einlesen der DAteien: Wir durchsuchen das Verzeichnis, in dem alle FB-Daten abgelegt sind.

# %%
filenames = glob.glob(path + '*.xlsx') # wir machen eine Liste mit den Filenames

# %%
len(filenames)
# Out:
# 14

# %%
filenames[0:2]
# Out:
# ['facebookdaten/FB_Posts_Migrationsstudie_16.04.2018_VF.xlsx',
#  'facebookdaten/FB_Posts_Migrationsstudie_16.05.2018_VF.xlsx']

# %%
df_addiert = []

# %%
df_addiert = [pd.read_excel(filename) for filename in filenames] # Listcomprehension

# %%
df_addiert[0].head(2)
# Out:
#    Code    channel                 time  \
# 0     0  SRF Sport  16.04.2018 23:27:00
# 1     0  SRF Sport  16.04.2018 23:11:49
#
#                                                 text  \
# 0  Die ZSC Lions verlieren das 3. Finalspiel gege...
# 1  Die besten Bilder des 3. Spiels der Playoff-Fi...
#
#                                                 link  reach  engagement_like  \
# 0  http://www.facebook.com/permalink.php?story_fb...  15707               17
# 1  http://www.facebook.com/permalink.php?story_fb...  17926               30
#
#    engagement_love  engagement_wow  engagement_haha  engagement_sorry  \
# 0                1               0                0                 1
# 1                1               0                1                 0
#
#    engagement_anger  comments  shares   type                            postId
# 0                 0         2       4  Video  126546190703867_2234729883218810
# ...

# %%
df_all = pd.concat(df_addiert, ignore_index=True, sort=True) #ignore_index=True ==> die alte Indexierung soll überschrieben werden.
#concat führt listen untereinaner zusammen

# %%
df_all.shape
# Out:
# (464, 20)

# %%
df_all.head(10)
# Out:
#    Code Kommentar  Unnamed: 16  Unnamed: 17  Unnamed: 18     channel  \
# 0     0       NaN          NaN          NaN          NaN   SRF Sport
# 1     0       NaN          NaN          NaN          NaN   SRF Sport
# 2     0       NaN          NaN          NaN          NaN   SRF Sport
# 3     0       NaN          NaN          NaN          NaN   SRF Sport
# 4     0       NaN          NaN          NaN          NaN  SRF Kultur
# 5     0       NaN          NaN          NaN          NaN    SRF News
# 6     0       NaN          NaN          NaN          NaN    SRF News
# 7     0       NaN          NaN          NaN          NaN  SRF Kultur
# 8     0       NaN          NaN          NaN          NaN    SRF News
# 9     0       NaN          NaN          NaN          NaN       SRF 3
#
#    comments  engagement_anger  engagement_haha  engagement_like  \
# 0         2                 0                0               17
# 1         1                 0                1               30
# ...

# %%
df_all.pop('Kommentar')
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#       ...
# 434    NaN
# 435    NaN
# 436    NaN
# 437    NaN
# 438    NaN
# 439    NaN
# 440    NaN
# 441    NaN
# 442    NaN
# 443    NaN
# 444    NaN
# 445    NaN
# 446    NaN
# 447    NaN
# 448    NaN
# 449    NaN
# 450    NaN
# 451    NaN
# 452    NaN
# 453    NaN
# 454    NaN
# 455    NaN
# 456    NaN
# 457    NaN
# 458    NaN
# 459    NaN
# 460    NaN
# 461    NaN
# 462    NaN
# 463    NaN
# Name: Kommentar, Length: 464, dtype: object

# %%
df_all.pop('Unnamed: 16')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 434   NaN
# 435   NaN
# 436   NaN
# 437   NaN
# 438   NaN
# 439   NaN
# 440   NaN
# 441   NaN
# 442   NaN
# 443   NaN
# 444   NaN
# 445   NaN
# 446   NaN
# 447   NaN
# 448   NaN
# 449   NaN
# 450   NaN
# 451   NaN
# 452   NaN
# 453   NaN
# 454   NaN
# 455   NaN
# 456   NaN
# 457   NaN
# 458   NaN
# 459   NaN
# 460   NaN
# 461   NaN
# 462   NaN
# 463   NaN
# Name: Unnamed: 16, Length: 464, dtype: float64

# %%
df_all.pop('Unnamed: 17')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 434   NaN
# 435   NaN
# 436   NaN
# 437   NaN
# 438   NaN
# 439   NaN
# 440   NaN
# 441   NaN
# 442   NaN
# 443   NaN
# 444   NaN
# 445   NaN
# 446   NaN
# 447   NaN
# 448   NaN
# 449   NaN
# 450   NaN
# 451   NaN
# 452   NaN
# 453   NaN
# 454   NaN
# 455   NaN
# 456   NaN
# 457   NaN
# 458   NaN
# 459   NaN
# 460   NaN
# 461   NaN
# 462   NaN
# 463   NaN
# Name: Unnamed: 17, Length: 464, dtype: float64

# %%
df_all.pop('Unnamed: 18')
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 434   NaN
# 435   NaN
# 436   NaN
# 437   NaN
# 438   NaN
# 439   NaN
# 440   NaN
# 441   NaN
# 442   NaN
# 443   NaN
# 444   NaN
# 445   NaN
# 446   NaN
# 447   NaN
# 448   NaN
# 449   NaN
# 450   NaN
# 451   NaN
# 452   NaN
# 453   NaN
# 454   NaN
# 455   NaN
# 456   NaN
# 457   NaN
# 458   NaN
# 459   NaN
# 460   NaN
# 461   NaN
# 462   NaN
# 463   NaN
# Name: Unnamed: 18, Length: 464, dtype: float64

# %%
df_all.to_csv("df_all.csv")

# %%
#Jetzt reduziere ich auf die Treffer bzw. auf die Codierungen mit 1 und 2

# %%
df_all.tail(10)
# Out:
#      Code     channel  comments  engagement_anger  engagement_haha  \
# 454     0    SRF News         5                 0                0
# 455     0   SRF Sport         2                 0                0
# 456     0    SRF News         5                 9                0
# 457     0  SRF Kultur         0                 0                0
# 458     0    SRF News        21                 3                9
# 459     0       SRF 3         0                 0                0
# 460     0    SRF News        59                 0              175
# 461     0   SRF Sport        11                 0                0
# 462     0    SRF News         1                 1                0
# 463     0       SRF 3       485                12             2290
#
#      engagement_like  engagement_love  engagement_sorry  engagement_wow  \
# 454                6                1                22               1
# 455               42                1                 0               0
# ...

# %%
df_all[df_all['Code'] != 0].sort_values("channel")
# Out:
#      Code     channel  comments  engagement_anger  engagement_haha  \
# 251     1     SRF DOK        40                 0                7
# 16      2  SRF Kultur         0                 0                0
# 41      1  SRF Kultur         1                 0                0
# 64      2  SRF Kultur         0                 0                0
# 92      2  SRF Kultur         1                 0                0
# 401     2  SRF Kultur         0                 0                0
# 90      2    SRF News         0                 0                0
# 171     2    SRF News        44                23                8
# 172     2    SRF News         6                 4                4
# 276     2    SRF News         5                 0                0
# 324     1    SRF News        30               111               41
# 329     1    SRF News         7                 1                1
# 412     2    SRF News         5                 0                5
# ...

# %%
df_all_treffer = df_all[df_all['Code'] != 0].sort_values("channel")

# %%
df_all_treffer
# Out:
#      Code     channel  comments  engagement_anger  engagement_haha  \
# 251     1     SRF DOK        40                 0                7
# 16      2  SRF Kultur         0                 0                0
# 41      1  SRF Kultur         1                 0                0
# 64      2  SRF Kultur         0                 0                0
# 92      2  SRF Kultur         1                 0                0
# 401     2  SRF Kultur         0                 0                0
# 90      2    SRF News         0                 0                0
# 171     2    SRF News        44                23                8
# 172     2    SRF News         6                 4                4
# 276     2    SRF News         5                 0                0
# 324     1    SRF News        30               111               41
# 329     1    SRF News         7                 1                1
# 412     2    SRF News         5                 0                5
# ...

# %%
df_all_treffer.to_csv("df_all_treffer.csv")

# %%
# !ls
# Out:
# Migrationsstudie.ipynb df_all_treffer.csv
# df_all.csv             facebookdaten
