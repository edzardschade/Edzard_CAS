# %% [markdown]
# # Sentiment
# - Sentiment detection ist bei Texten ein relativ altes Thema
# - Seit Deep Learning sind die "alten" Methoden abgeschlagen
# - Allerdings ist es nicht ganz trivial einen eigenen Classifier für Deep Learning zu schreiben
# - Wenn ihr est trotzdem mal probieren wollt, dann findet ihr eine Anleitung in meinem Blog Post:
#     - https://www.liip.ch/en/blog/sentiment-detection-with-keras-word-embeddings-and-lstm-deep-learning-networks

# %%
from textblob_de import TextBlobDE
from textblob import TextBlob

# %%
TextBlob(u"Das Auto ist sehr schön!").sentiment
#TextBlob(u"Das Auto ist sehr schön!").sentiment
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in _read(path, encoding, comment)
#     608             yield line
# --> 609     raise StopIteration
#     610
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-915c926e17df> in <module>()
# ----> 1 TextBlobDE(u"Das Auto ist sehr schön!").sentiment
#       2 #TextBlob(u"Das Auto ist sehr schön!").sentiment
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/blob.py in sentiment(self)
#     668         _subjectivity = 0
#     669         for s in self.sentences:
# --> 670             _polarity += s.polarity
#     671             _subjectivity += s.subjectivity
#     672         try:
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/blob.py in polarity(self)
#     430         :rtype: float
#     431         """
# --> 432         return self.sentiment[0]
#     433
#     434     @cached_property
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/blob.py in sentiment(self)
#     422         :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     423         """
# --> 424         return self.analyzer.analyze(self.raw)
#     425
#     426     @cached_property
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/sentiments.py in analyze(self, text)
#     139         """
#     140         if self.lemmatize:
# --> 141             text = self._lemmatize(text)
#     142         return self.RETURN_TYPE(*pattern_sentiment(text))
#     143
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/sentiments.py in _lemmatize(self, raw)
#     144     def _lemmatize(self, raw):
#     145         # returns a list of [(lemma1, tag1), (lemma2, tag2), ...]
# --> 146         _lemmas = self.lemmatizer.lemmatize(raw)
#     147         # pass to analyzer as a string
#     148         _lemmas = " ".join([l for l, t in _lemmas])
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/lemmatizers.py in lemmatize(self, text)
#      50         if text.strip() == "":
#      51             return []
# ---> 52         parsed_sentences = self._parse_text(text)
#      53         _lemmalist = []
#      54         for s in parsed_sentences:
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/lemmatizers.py in _parse_text(self, text)
#      93         text = text.replace("/", " FORWARDSLASH ")
#      94         _tokenized = " ".join(self.tokenizer.tokenize(text))
# ---> 95         parsed_text = pattern_parse(_tokenized, tokenize=False, lemmata=True)
#      96         return parsed_text.split('\n')
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/de/__init__.py in parse(s, *args, **kwargs)
#     255     """ Returns a tagged Unicode string.
#     256     """
# --> 257     return parser.parse(s, *args, **kwargs)
#     258
#     259
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1181             # Lemmatizer.
#    1182             if lemmata:
# -> 1183                 s[i] = self.find_lemmata(s[i], **kwargs)
#    1184         # Slash-formatted tagged string.
#    1185         # With collapse=False (or split=True), returns raw list
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/de/__init__.py in find_lemmata(self, tokens, **kwargs)
#     215
#     216     def find_lemmata(self, tokens, **kwargs):
# --> 217         return find_lemmata(tokens)
#     218
#     219     def find_tags(self, tokens, **kwargs):
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/de/__init__.py in find_lemmata(tokens)
#     202             lemma = singularize(word)
#     203         if pos.startswith(("VB", "MD")):
# --> 204             lemma = conjugate(word, INFINITIVE) or word
#     205         token.append(lemma.lower())
#     206     return tokens
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in conjugate(self, verb, *args, **kwargs)
#    2206         i2 = self._format.get(self._default.get(id))
#    2207         i3 = self._format.get(self._default.get(self._default.get(id)))
# -> 2208         b = self.lemma(verb, parse=kwargs.get("parse", True))
#    2209         v = []
#    2210         # Get the verb lexeme and return the requested index.
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in lemma(self, verb, parse)
#    2170         """
#    2171         if dict.__len__(self) == 0:
# -> 2172             self.load()
#    2173         if verb.lower() in self._inverse:
#    2174             return self._inverse[verb.lower()]
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in load(self)
#    2125         # have,,,has,,having,,,,,had,had,haven't,,,hasn't,,,,,,,hadn't,hadn't
#    2126         id = self._format[TENSES_ID[INFINITIVE]]
# -> 2127         for v in _read(self._path):
#    2128             v = v.split(",")
#    2129             dict.__setitem__(self, v[id], v)
#
# RuntimeError: generator raised StopIteration

# %%
blob = TextBlobDE(u"Das ist ein hässliches Auto.")     
blob.sentiment
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in _read(path, encoding, comment)
#     608             yield line
# --> 609     raise StopIteration
#     610
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-792616ec2f3a> in <module>()
#       1 blob = TextBlobDE(u"Das ist ein hässliches Auto.")
# ----> 2 blob.sentiment
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/blob.py in sentiment(self)
#     668         _subjectivity = 0
#     669         for s in self.sentences:
# --> 670             _polarity += s.polarity
#     671             _subjectivity += s.subjectivity
#     672         try:
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/blob.py in polarity(self)
#     430         :rtype: float
#     431         """
# --> 432         return self.sentiment[0]
#     433
#     434     @cached_property
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/decorators.py in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/blob.py in sentiment(self)
#     422         :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     423         """
# --> 424         return self.analyzer.analyze(self.raw)
#     425
#     426     @cached_property
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/sentiments.py in analyze(self, text)
#     139         """
#     140         if self.lemmatize:
# --> 141             text = self._lemmatize(text)
#     142         return self.RETURN_TYPE(*pattern_sentiment(text))
#     143
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/sentiments.py in _lemmatize(self, raw)
#     144     def _lemmatize(self, raw):
#     145         # returns a list of [(lemma1, tag1), (lemma2, tag2), ...]
# --> 146         _lemmas = self.lemmatizer.lemmatize(raw)
#     147         # pass to analyzer as a string
#     148         _lemmas = " ".join([l for l, t in _lemmas])
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/lemmatizers.py in lemmatize(self, text)
#      50         if text.strip() == "":
#      51             return []
# ---> 52         parsed_sentences = self._parse_text(text)
#      53         _lemmalist = []
#      54         for s in parsed_sentences:
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob_de/lemmatizers.py in _parse_text(self, text)
#      93         text = text.replace("/", " FORWARDSLASH ")
#      94         _tokenized = " ".join(self.tokenizer.tokenize(text))
# ---> 95         parsed_text = pattern_parse(_tokenized, tokenize=False, lemmata=True)
#      96         return parsed_text.split('\n')
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/de/__init__.py in parse(s, *args, **kwargs)
#     255     """ Returns a tagged Unicode string.
#     256     """
# --> 257     return parser.parse(s, *args, **kwargs)
#     258
#     259
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1170             # Tagger (required by chunker, labeler & lemmatizer).
#    1171             if tags or chunks or relations or lemmata:
# -> 1172                 s[i] = self.find_tags(s[i], **kwargs)
#    1173             else:
#    1174                 s[i] = [[w] for w in s[i]]
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/de/__init__.py in find_tags(self, tokens, **kwargs)
#     227         # We restore the "ß" after parsing.
#     228         tokens_ss = [t.replace("ß", "ss") for t in tokens]
# --> 229         tokens_ss = _Parser.find_tags(self, tokens_ss, **kwargs)
#     230         return [[w] + tokens_ss[i][1:] for i, w in enumerate(tokens)]
#     231
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in find_tags(self, tokens, **kwargs)
#    1118                    language = kwargs.get("language", self.language),
#    1119                     default = kwargs.get("default", self.default),
# -> 1120                         map = kwargs.get("map", None))
#    1121
#    1122     def find_chunks(self, tokens, **kwargs):
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in find_tags(tokens, lexicon, model, morphology, context, entities, default, language, map, **kwargs)
#    1526             # Use suffix rules (e.g., -ly = RB).
#    1527             elif morphology is not None:
# -> 1528                 tagged[i] = morphology.apply([token, default[0]], prev, next)
#    1529             # Use suffix rules (English default).
#    1530             elif language == "en":
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in apply(self, token, previous, next)
#     776         """
#     777         w = token[0]
# --> 778         for r in self:
#     779             if r[1] in self._cmd: # Rule = ly hassuf 2 RB x
#     780                 f, x, pos, cmd = bool(0), r[0], r[-2], r[1].lower()
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in __iter__(self)
#     441
#     442     def __iter__(self):
# --> 443         return self._lazy("__iter__")
#     444
#     445     def __contains__(self, *args):
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in _lazy(self, method, *args)
#     430         """
#     431         if list.__len__(self) == 0:
# --> 432             self.load()
#     433             setattr(self, method, types.MethodType(getattr(list, method), self))
#     434         return getattr(list, method)(self, *args)
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in load(self)
#     770     def load(self):
#     771         # ["NN", "s", "fhassuf", "1", "NNS", "x"]
# --> 772         list.extend(self, (x.split() for x in _read(self._path)))
#     773
#     774     def apply(self, token, previous=(None, None), next=(None, None)):
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pattern/text/__init__.py in <genexpr>(.0)
#     770     def load(self):
#     771         # ["NN", "s", "fhassuf", "1", "NNS", "x"]
# --> 772         list.extend(self, (x.split() for x in _read(self._path)))
#     773
#     774     def apply(self, token, previous=(None, None), next=(None, None)):
#
# RuntimeError: generator raised StopIteration

# %% [markdown]
# # Spracherkennung
# - wiederum ein einfaches Thema wird z.B. von TextblobDE unterstützt

# %%
TextBlobDE(u"Ich gehe ins Schwimmbad").detect_language()
# Out:
# u'de'

# %%
TextBlobDE(u"Ide plywac").detect_language()
# Out:
# u'pl'

# %%
TextBlobDE(u"I am going to the swimming pool").detect_language()
# Out:
# u'en'

# %% [markdown]
# # Spellchecking

# %% [markdown]
# - Geht aktuell leider nur auf englisch.
# - Damit könnt ihr zumindest Eure englisch sprachigen Kollegen kontrollieren.

# %%
from textblob import TextBlob
blob = TextBlob(u'Writing easy sentences in english is easy but thei do hafe to be korrekt.')
blob.correct()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/_text.py in _read(path, encoding, comment)
#     364             yield line
# --> 365     raise StopIteration
#     366
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-66a391d8571e> in <module>()
#       1 from textblob import TextBlob
#       2 blob = TextBlob(u'Writing easy sentences in english is easy but thei do hafe to be korrekt.')
# ----> 3 blob.correct()
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/blob.py in correct(self)
#     572         tokens = nltk.tokenize.regexp_tokenize(self.raw, "\w+|[^\w\s]|\s")
#     573         corrected = (Word(w).correct() for w in tokens)
# --> 574         ret = ''.join(corrected)
#     575         return self.__class__(ret)
#     576
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/blob.py in <genexpr>(.0)
#     571         # regex matches: word or punctuation or whitespace
#     572         tokens = nltk.tokenize.regexp_tokenize(self.raw, "\w+|[^\w\s]|\s")
# --> 573         corrected = (Word(w).correct() for w in tokens)
#     574         ret = ''.join(corrected)
#     575         return self.__class__(ret)
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/blob.py in correct(self)
#     125         .. versionadded:: 0.6.0
#     126         '''
# --> 127         return Word(self.spellcheck()[0][0])
#     128
#     129     @cached_property
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/blob.py in spellcheck(self)
#     117         .. versionadded:: 0.6.0
#     118         '''
# --> 119         return suggest(self.string)
#     120
#     121     def correct(self):
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/en/__init__.py in suggest(w)
#     121     """ Returns a list of (word, confidence)-tuples of spelling corrections.
#     122     """
# --> 123     return spelling.suggest(w)
#     124
#     125 def polarity(s, **kwargs):
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/_text.py in suggest(self, w)
#    1384             based on the probability of known words with edit distance 1-2 from the given word.
#    1385         """
# -> 1386         if len(self) == 0:
#    1387             self.load()
#    1388         if len(w) == 1:
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/_text.py in __len__(self)
#      90         return self._lazy("__repr__")
#      91     def __len__(self):
# ---> 92         return self._lazy("__len__")
#      93     def __iter__(self):
#      94         return self._lazy("__iter__")
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/_text.py in _lazy(self, method, *args)
#      83         """
#      84         if dict.__len__(self) == 0:
# ---> 85             self.load()
#      86             setattr(self, method, types.MethodType(getattr(dict, method), self))
#      87         return getattr(dict, method)(self, *args)
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/textblob/_text.py in load(self)
#    1328
#    1329     def load(self):
# -> 1330         for x in _read(self._path):
#    1331             x = x.split()
#    1332             dict.__setitem__(self, x[0], int(x[1]))
#
# RuntimeError: generator raised StopIteration

# %%
blob.words[10].spellcheck()
# Out:
# [(u'have', 0.9694698862059395),
#  (u'safe', 0.013044684984734944),
#  (u'hare', 0.009991673605328892),
#  (u'hate', 0.005550929780738274),
#  (u'haze', 0.0011101859561476548),
#  (u'hale', 0.0002775464890369137),
#  (u'chafe', 0.0002775464890369137),
#  (u'cafe', 0.0002775464890369137)]
