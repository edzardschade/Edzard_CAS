# %%
import pandas as pd
import numpy as np

# %%
df_investitionen = pd.read_excel("../snb-data-fdiaustabsa-de-all-20171215_0900.xlsx")

# %%
df_investitionen.head(5)
# Out:
#         Datenportal der Schweizerischen Nationalbank            Unnamed: 1  \
# 0  Hinweis: Die vorliegende Datei enthält die Ang...                   NaN
# 1  Für das bessere Verständnis der Werte in diese...                   NaN
# 2  Aus urheberrechtlichen Gründen kann das Herunt...                   NaN
# 3                                                NaN                   NaN
# 4                                            Einheit  In Millionen Franken
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9     ...     Unnamed: 67 Unnamed: 68 Unnamed: 69  \
# ...
