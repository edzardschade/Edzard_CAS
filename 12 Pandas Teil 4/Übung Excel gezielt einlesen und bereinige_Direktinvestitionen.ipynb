# %%
import pandas as pd
import numpy as np

# %%
df_investitionen = pd.read_excel("../snb-data-fdiaustabsa-de-all-20171215_0900.xlsx", header=15) 
# so deffinieren wir, welche Zeile zum header werden soll

# %%
list1 = list(df_investitionen) # macht mir eine Liste mit allen Headers

# %%
df_investitionen = pd.read_excel("../snb-data-fdiaustabsa-de-all-20171215_0900.xlsx", header=17)

# %%
list2 = list(df_investitionen)
list2
# Out:
# ['Sektoren und Branchen ',
#  'Industrie - Total',
#  'Industrie - Textilien und Bekleidung',
#  'Industrie - Chemie und Kunststoffe',
#  'Industrie - Metalle und Maschinen',
#  'Industrie - Elektronik, Energie, Optik und Uhren',
#  'Industrie - Übrige Industrien und Bau',
#  'Dienste - Total',
#  'Dienste - Handel',
#  'Dienste - Finanz- und Holdinggesellschaften - Total',
#  'Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
#  'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - Total',
#  'Dienste - Finanz- und Holdinggesellschaften - ausländisch beherrscht - davon Special Purpose Entities',
#  'Dienste - Banken',
#  'Dienste - Versicherungen',
#  'Dienste - Transporte und Kommunikation',
#  'Dienste - Übrige Dienste',
#  'Total',
#  'Total ohne ausländisch beherrschte Finanz- und Holdinggesellschaften',
#  'Pro memoria: Grundstücks- und Wohnungswesen',
#  'Pro memoria: Total inkl. Grundstücks- und Wohnungswesen',
# ...

# %%
list3 = []
for elem1, elem2 in zip(list1, list2):
    elem = elem1 + " "+elem2
    list3.append(elem)

# %%
list3
# Out:
# ['Kapitalart Sektoren und Branchen ',
#  'Beteiligungskapital ohne reinvestierte Erträge Industrie - Total',
#  'Beteiligungskapital ohne reinvestierte Erträge.1 Industrie - Textilien und Bekleidung',
#  'Beteiligungskapital ohne reinvestierte Erträge.2 Industrie - Chemie und Kunststoffe',
#  'Beteiligungskapital ohne reinvestierte Erträge.3 Industrie - Metalle und Maschinen',
#  'Beteiligungskapital ohne reinvestierte Erträge.4 Industrie - Elektronik, Energie, Optik und Uhren',
#  'Beteiligungskapital ohne reinvestierte Erträge.5 Industrie - Übrige Industrien und Bau',
#  'Beteiligungskapital ohne reinvestierte Erträge.6 Dienste - Total',
#  'Beteiligungskapital ohne reinvestierte Erträge.7 Dienste - Handel',
#  'Beteiligungskapital ohne reinvestierte Erträge.8 Dienste - Finanz- und Holdinggesellschaften - Total',
#  'Beteiligungskapital ohne reinvestierte Erträge.9 Dienste - Finanz- und Holdinggesellschaften - schweizerisch beherrscht',
# ...

# %%
df_investitionen = pd.read_excel("../snb-data-fdiaustabsa-de-all-20171215_0900.xlsx", header=17)
df_investitionen.columns = list3 # df.columns = holt alle headers (blöde Benennung der Funktion)

# %%
df_investitionen
# Out:
#     Kapitalart Sektoren und Branchen   \
# 0                                 NaN
# 1                              1998.0
# 2                              1999.0
# 3                              2000.0
# 4                              2001.0
# 5                              2002.0
# 6                              2003.0
# 7                              2004.0
# 8                              2005.0
# 9                              2006.0
# 10                             2007.0
# 11                             2008.0
# 12                             2009.0
# 13                             2010.0
# 14                             2011.0
# 15                             2012.0
# 16                             2013.0
# 17                             2014.0
# 18                             2015.0
# 19                             2016.0
#
#    Beteiligungskapital ohne reinvestierte Erträge Industrie - Total  \
# 0                        EPB@SNB.fdiaustabsa{D0_0,T0}
# ...

# %%
df_investitionen[1:]
# Out:
#     Kapitalart Sektoren und Branchen   \
# 1                              1998.0
# 2                              1999.0
# 3                              2000.0
# 4                              2001.0
# 5                              2002.0
# 6                              2003.0
# 7                              2004.0
# 8                              2005.0
# 9                              2006.0
# 10                             2007.0
# 11                             2008.0
# 12                             2009.0
# 13                             2010.0
# 14                             2011.0
# 15                             2012.0
# 16                             2013.0
# 17                             2014.0
# 18                             2015.0
# 19                             2016.0
#
#    Beteiligungskapital ohne reinvestierte Erträge Industrie - Total  \
# 1                                                6374
# 2                                                4606
# ...
