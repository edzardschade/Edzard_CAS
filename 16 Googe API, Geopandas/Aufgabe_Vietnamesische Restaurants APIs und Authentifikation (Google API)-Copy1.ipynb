# %% [markdown]
# # APIs und Authentifikation (Google API)

# %% [markdown]
# Wir haben uns vor langer, langer Zeit die Erdbeben-Applikation angeschaut. Die Nutzung ist zwar begrenzt, doch es für deren Nutzung keine weitere Zulassung notwendig. Das ist bei den meisten anderen APIs nicht der Fall. In der Regel verlangen die Besitzer einer API Authentifikation der Nutzer. So können sie kontrollieren, wer wieviel nutzt. Denn auch eine API-Abfrage beansprucht Rechenkraft. Bei Millionen Abfragen kann das schnell ins Geld gehen. Es gibt dabei verschiedene API-Typen: REST, SOAP, XML-RCP oder JSON-RPC. Was die verschiedenen Vorteile dieser API-Technologien sind, schlägt ihr am besten nach. Die gängigsten sind heute REST und SOAP. Die trifft man immer wieder.

# %% [markdown]
# Wie man sich authentifiziert, wollen wir uns nun gemeinsam anschauen. Wir tun das mit der Google Maps API. Zu allererst müssen wir eine Key kreieren. Dafür brauchen wir eine Gmail-Konto und eine Kreditkarte. Wir werden keinen Rappen ausgeben, die erste 100'000 Aufrufe sind gratis. Die Kreditkarte ist trotzdem nötig. Als erstes besuchen wir [also die Google-Maps-Plattform](https://cloud.google.com/maps-platform).

# %% [markdown]
# ## Die Google API
# Die API kann man für verschiedene Sachen verwenden: Um Distanzen zu berechnen, um Standorte mit Geo-Daten auszustatten, oder um Standorte zu suchen. Natürlich nicht einzelne Standorte, sondern ganz viele. In diesem Beispiel werden wir uns bestimmte Standorte suchen.

# %% [markdown]
# Nachdem ihr Euch oben bei Google angemeldet habt, müsst ihr eine API Key generieren und abspeichern. Nun gehen wir nur Places API und Places Search. Das [ist hier](https://developers.google.com/places/web-service/intro).

# %% [markdown]
# Um Eure API keys zu finden, geht ihr zu API & Services, Credentials. [Hier](https://console.cloud.google.com/apis/credentials?project=clear-canyon-166711)

# %% [markdown]
# ### Das italienische Restaurant mit den meisten Sternen bei Google Maps?

# %% [markdown]
# Wir werden mir der Textsearch-Option arbeiten: ```https://maps.googleapis.com/maps/api/place/textsearch/output?parameters```. Wir geben ein:
# - https://maps.googleapis.com/maps/api/place/textsearch/json
# - query=italienische+restaurants+in+zurich
# - fields=formatted_address,name,rating,opening_hours,pagetoken
# - key=XXXXXX

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=vietnamesische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4"

# %%
api_query = url+query+fields+locationbias+key

# %%
api_query
# Out:
# 'https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4'

# %% [markdown]
# importieren wir requests

# %%
import requests
# Out:
# /Users/edzardschade/.virtualenvs/erstesVE/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.23) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
r = requests.get(api_query)
result = r.json()

# %%
len(result)
# Out:
# 3

# %%
for key in result:
    print(key)
# Out:
# html_attributions
# results
# status

# %%
result['results'][0]['geometry']['location']
# Out:
# {'lat': 47.3621815, 'lng': 8.5186647}

# %%
result['results'][0]['name']
# Out:
# 'Vietnam'

# %%
len(result['results'])
# Out:
# 17

# %%
new_lst = []

for beiz in result['results']:
    address = beiz['formatted_address']
    name = beiz['name']
    rating = beiz['rating']
    lat = beiz['geometry']['location']['lat']
    long = beiz['geometry']['location']['lng']
    
    mini_dict = {'Addresse': address, 
                 'Name': name,
                 'Rating': rating,
                 'Lat':lat,
                 'Lng':long}
    
    new_lst.append(mini_dict)

# %%
import pandas as pd

# %%
pd.DataFrame(new_lst)
# Out:
#                                              Addresse        Lat       Lng  \
# 0       Uetlibergstrasse 77, 8045 Zürich, Switzerland  47.362181  8.518665
# 1            Langstrasse 13, 8004 Zürich, Switzerland  47.375009  8.524481
# 2        Gasometerstrasse 7, 8005 Zürich, Switzerland  47.383767  8.528473
# 3       Zypressenstrasse 50, 8004 Zürich, Switzerland  47.377314  8.512907
# 4            Sihlstrasse 97, 8001 Zürich, Switzerland  47.373006  8.532775
# 5   Schwamendingenstrasse 10, 8050 Zürich, Switzer...  47.408054  8.547129
# 6          Kehlhofstrasse 4, 8003 Zürich, Switzerland  47.369887  8.518454
# 7   Birmensdorferstrasse 126, 8003 Zürich, Switzer...  47.370265  8.520779
# 8           Josefstrasse 42, 8005 Zürich, Switzerland  47.381653  8.532984
# 9           Rolandstrasse 9, 8004 Zürich, Switzerland  47.378962  8.526647
# 10  Schaffhauserstrasse 475, 8052 Zürich, Switzerland  47.420214  8.548364
# 11          Kanonengasse 31, 8004 Zürich, Switzerland  47.378017  8.530001
# 12        Militärstrasse 84, 8004 Zürich, Switzerland  47.378798  8.529716
# 13         Bülachstrasse 25, 8057 Zürich, Switzerland  47.402376  8.547695
# 14  Schaffhauserstrasse 127, 8057 Zürich, Switzerland  47.396610  8.540545
# 15          Hardstrasse 320, 8005 Zürich, Switzerland  47.390250  8.522477
# 16  Birmensdorferstrasse 93, 8003 Zürich, Switzerland  47.370774  8.523064
#
#                   Name  Rating
# 0              Vietnam     4.4
# 1          Pho Vietnam     4.4
# 2         Co Chin Chin     4.4
# 3               Pho 50     4.3
# 4               Saigon     4.3
# 5   ASIAWAY RESTAURANT     4.5
# 6            Chez Nhan     4.1
# 7         Petit Saigon     3.9
# 8               Pho Na     4.2
# 9           comingsoon     4.4
# 10            Đồng Quê     4.0
# 11           Viet-Thai     4.5
# 12               Thach     4.6
# 13          Pho Saigon     4.6
# 14              Hang's     4.8
# 15            Hua Thai     4.0
# 16             Mai-Wok     3.3

# %% [markdown]
# Aber, das sind nur 20. Wir wollen mehr. Dafür müssen wir mit diesem Nexttoken arbeiten.

# %%
import time

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=vietnamesische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&" # an den Key ein "&" anhängen
pagetoken = ''

result = range(4)
while len(result) > 3: 
    
    print(len(result))

    api_query = url+query+fields+locationbias+key+pagetoken
    print(api_query)
    time.sleep(2)
    r = requests.get(api_query)
    result = r.json()
    
    for elem in result['results']:
        address = elem['formatted_address']
        name = elem['name']
        rating = elem['rating']
        lat = elem['geometry']['location']['lat']
        long = elem['geometry']['location']['lng']
    
        mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lat':lat,
                     'Lng':long}
    
        new_list.append(mini_dict)
        
    
    if len(result) > 3:
        pagetoken = 'pagetoken='+result['next_page_token'] 
    else:
        break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+zurich&fields=formatted_address,name,rating,opening_hours,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&

# %% [markdown]
# Das ist leider nicht zufriedenstellend, denn offenbar begrenzt sich Google selber. Wir müssen die nexttoken Suche mit einer Suche nach Städten erweitern. Suchen wir "schweizer städte .csv" bei Google.

# %% [markdown]
# ## Ergänzung Schweizer Städte

# %%
t = pd.read_html("https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_der_Schweiz#St%C3%A4dte_mit_mindestens_10'000_Einwohnern")

# %%
t
# Out:
# [        0                       1        2        3        4        5  \
#  0    Rang                    Name   F 1995   F 2000   F 2005   F 2010
#  1      1.                Zürich 1  343'869  337'900  347'517  372'857
#  2      2.                  Genf 1  173'549  174'999  178'722  187'470
#  3      3.                 Basel 1  174'007  166'009  163'930  163'216
#  4      4.                  Bern 1  127'469  122'484  122'178  124'381
#  5      5.              Lausanne 1  115'878  114'889  117'388  127'821
#  6      6.            Winterthur 1   87'654   88'767   93'546  101'308
#  7      7.                Luzern 1   58'847   57'023   57'533   77'491
#  8      8.            St. Gallen 1   71'877   69'836   70'316   72'959
#  9      9.                Lugano 1   26'000   25'872   49'223   54'667
#  10    10.           Biel/Bienne 1   50'733   48'840   48'735   51'203
#  11    11.                  Thun 1   39'094   39'981   41'138   42'623
#  12    12.                   Köniz   36'335   37'196   37'250   38'823
#  13    13.     La Chaux-de-Fonds 1   37'375   36'747   36'809   37'504
#  14    14.              Freiburg 1   32'501   31'691   33'008   34'897
#  15    15.          Schaffhausen 1   34'073   33'274   33'569   34'943
#  16    16.                  Chur 1   30'091   31'310   32'409   33'756
#  17    17.                 Vernier   28'423   28'727   30'020   32'844
#  18    18.             Neuenburg 1   31'768   31'639   32'117   33'815
#  19    19.                   Uster   26'139   27'893   29'855   32'265
#  20    20.                Sitten 1   26'065   27'145   28'510   30'363
#  21    21.                   Lancy   25'043   25'479   26'905   28'631
#  22    22.     Yverdon-les-Bains 1   23'234   23'144   24'415   27'511
#  23    23.                   Emmen   26'746   26'628   26'906   28'031
#  24    24.                   Zug 1   22'778   22'710   24'179   26'327
#  25    25.                  Kriens   24'156   24'394   25'336   26'324
#  26    26.   Rapperswil-Jona 1 / 3   15'742   16'733   17'689   26'212
#  27    27.               Dübendorf   20'906   22'011   22'707   24'831
#  28    28.                Dietikon   20'953   21'060   22'178   23'624
#  29    29.                Montreux   20'982   21'969   23'023   24'579
#  ..    ...                     ...      ...      ...      ...      ...
#  119  119.                    Belp    8'334    8'994    9'565   10'221
#  120  120.                    Worb   11'100   10'779   11'137   11'364
#  121  121.             Bassersdorf    6'808    7'373    9'314   11'077
#  122  122.                    Arth    9'288    9'963    9'925   10'699
#  123  123.               Pfäffikon    8'947    9'332    9'951   10'627
#  124  124.            Altstätten 1   10'293   10'283   10'547   10'819
#  125  125.                 Ittigen   10'836   10'997   10'839   10'946
#  126  126.              Zofingen 1    8'513    8'601   10'228   10'803
#  127  127.      La Tour-de-Peilz 1   10'182   10'118   10'474   10'786
#  128  128.                   Davos   11'232   12'013   10'817   11'166
#  129  129.         Chêne-Bougeries    9'624    9'709   10'061   10'400
#  130  130.                 Brugg 1    9'208    9'162    9'037   10'386
#  131  131.            Spreitenbach    8'797    9'045    9'982   10'465
#  132  132.              Weinfelden    9'301    9'366    9'519   10'383
#  133  133.              Veyrier GE    7'756    8'986    9'553   10'003
#  134  134.                 Oberwil    8'843    9'433    9'962   10'442
#  135  135.       Val-de-Travers NE   10'896   10'794   10'834   10'812
#  136  136.                  Hinwil    8'705    9'081    9'761   10'379
#  137  137.                  Möhlin    7'832    8'292    8'884   10'023
#  138  138.              Romanshorn    7'199    8'432    9'008    9'711
#  139  139.               Männedorf    7'699    8'244    9'582   10'442
#  140  140.                Le Locle   10'977   10'349   10'226   10'049
#  141  141.  Neuhausen am Rheinfall   10'626   10'062    9'880   10'185
#  142  142.                  Flawil    9'154    9'320    9'971   10'150
#  143  143.              Birsfelden   11'049   10'243   10'240   10'352
#  144  144.         Plan-les-Ouates    8'974    9'265    9'548    9'807
#  145  145.                Sarnen 2    8'799    9'218    9'445    9'891
#  146  146.                   Aesch    9'555    9'801    9'880   10'219
#  147  147.              Zollikofen    8'817    9'101    9'548    9'690
#  148  148.                   Risch    6'073    7'218    8'419    9'085
#
#             6                 7
#  0     F 2015            Kanton
#  1    396'027            Zürich
#  2    194'565              Genf
#  3    175'131       Basel-Stadt
#  4    140'634              Bern
#  5    135'629             Waadt
#  6    106'778            Zürich
#  7     81'284            Luzern
#  8     75'310        St. Gallen
#  9     63'668            Tessin
#  10    53'667              Bern
#  11    43'303              Bern
#  12    39'998              Bern
#  13    39'027         Neuenburg
#  14    38'288          Freiburg
#  15    35'927      Schaffhausen
#  16    34'547        Graubünden
#  17    34'477              Genf
#  18    33'641         Neuenburg
#  19    33'412            Zürich
#  20    33'296            Wallis
#  21    30'919              Genf
#  22    29'406             Waadt
#  23    29'292            Luzern
#  24    28'603               Zug
#  25    27'229            Luzern
#  26    26'875        St. Gallen
#  27    26'759            Zürich
#  28    26'277            Zürich
#  29    26'208             Waadt
#  ..       ...               ...
#  119   11'466              Bern
#  120   11'423              Bern
#  121   11'404            Zürich
#  122   11'301            Schwyz
#  123   11'275            Zürich
#  124   11'273        St. Gallen
#  125   11'250              Bern
#  126   11'210            Aargau
#  127   11'197             Waadt
#  128   11'136        Graubünden
#  129   11'105              Genf
#  130   11'104            Aargau
#  131   11'040            Aargau
#  132   11'039           Thurgau
#  133   10'999              Genf
#  134   10'917  Basel-Landschaft
#  135   10'854         Neuenburg
#  136   10'799            Zürich
#  137   10'746            Aargau
#  138   10'659           Thurgau
#  139   10'537            Zürich
#  140   10'433         Neuenburg
#  141   10'331      Schaffhausen
#  142   10'323        St. Gallen
#  143   10'313  Basel-Landschaft
#  144   10'281              Genf
#  145   10'232          Obwalden
#  146   10'155  Basel-Landschaft
#  147   10'097              Bern
#  148   10'036               Zug
#
#  [149 rows x 8 columns],
#                        0                     1                      2  \
#  0                 Stadt                Bezirk                 Kanton
#  1               Aarberg               Seeland                   Bern
#  20                 2360
#  21                 2558
#  22                  865
#  23                  877
#  24                 1798
#  25                 3227
#  26                 4281
#  27                 2893
#  28                 3593
#  29                 1123
#  ..                  ...
#  73                 4235
#  74                  435
#  75                 3964
#  76                 8647
#  77                  948
#  78                 1519
#  79                 3596
#  80                 4210
#  81                  769
#  82                 1179
#  83                 4765
#  84                  792
#  85                 3483
#  86                  411
#  87                 6983
#  88                 3320
#  89                 2985
#  90                 8059
#  91                 2717
#  92                 5201
#  93                 5369
#  94                  400
#  95                 4180
#  96                 6550
#  97                 1328
#  98                 4532
#  99                 1889
#  100                  90
#  101                2414
#  102                7101
#
#  [103 rows x 4 columns],
#                             0                         1  \
#  0                        Ort                  Gemeinde
#  1                     Altreu                   Selzach
#  2                  Arconciel                 Arconciel
#  3                      Asuel                     Asuel
#  4                     Bavois                    Bavois
#  5        Belmont-sur-Yverdon       Belmont-sur-Yverdon
#  6                    Bercher                   Bercher
#  7                 Biberstein                Biberstein
#  8              La Bonneville                  Engollon
#  9                    Bourjod                 Pailly VD
#  10       Bremgarten bei Bern       Bremgarten bei Bern
#  11         Büren an der Aare         Büren an der Aare
#  12                   Bürglen                   Bürglen
#  13                 Cassarate                    Lugano
#  14                 Champvent                 Champvent
#  15              Château-d’Œx              Château-d’Œx
#  16                   Chillon                   Veytaux
#  17                 Corbières                 Corbières
#  18                 Dommartin                 Dommartin
#  19                  Epeisses                    Avully
#  20                Eschenbach                Eschenbach
#  21            Falkenstein SO              Niedergösgen
#  22                      Font                      Font
#  23                    Fridau                 Fulenbach
#  24                   Fruence        Châtel-Saint-Denis
#  25               Glanzenberg          Unterengstringen
#  26                Gottlieben                Gottlieben
#  27                   Granges                    Siders
#  28                  Grasburg             Schwarzenburg
#  29                  Gümmenen                 Mühleberg
#  ..                       ...                       ...
#  43     Montagny-près-Yverdon     Montagny-près-Yverdon
#  44                Montricher                Montricher
#  45               Montsalvens                      Broc
#  46                   Mülenen  Reichenbach im Kandertal
#  47             Niedergesteln             Niedergesteln
#  48                   Nugerol               Le Landeron
#  49                  Oltingen                  Oltingen
#  50                 Palézieux                 Palézieux
#  51            Peney-le-Jorat            Peney-le-Jorat
#  52                      Pfyn                      Pfyn
#  53             Pont-la-Ville             Pont-la-Ville
#  54                 Richensee                 Hitzkirch
#  55                Rothenburg                Rothenburg
#  56              Saint-Cergue              Saint-Cergue
#  57              Saint-Martin              Saint-Martin
#  58              Sainte-Croix              Sainte-Croix
#  59             Sankt Andreas                   Cham ZG
#  60             Schwarzenbach                 Jonschwil
#  61                 Surpierre                 Surpierre
#  62                   Tannegg                Fischingen
#  63                   Uttigen                   Uttigen
#  64                   Vaulruz                   Vaulruz
#  65                 Vaumarcus                 Vaumarcus
#  66                 Villarzel                 Villarzel
#  67                   Vissoie                   Vissoie
#  68                  Vuippens                   Marsens
#  69                    Weesen                    Weesen
#  70  Weissenburg im Simmental                Därstetten
#  71                    Wimmis                    Wimmis
#  72                  Wolhusen                  Wolhusen
#
#                             2                 3                   4
#  0                     Bezirk            Kanton  Einwohner(VZ 2000)
#  1                     Lebern         Solothurn                 180
#  2                      Saane          Freiburg                 656
#  3                 Porrentruy              Jura                 216
#  4                       Orbe             Waadt                 727
#  5                    Yverdon             Waadt                 247
#  6                  Echallens             Waadt                 878
#  7                      Aarau            Aargau                1101
#  8                 Val-de-Ruz         Neuenburg                   0
#  9                  Echallens             Waadt                   0
#  10           Bern-Mittelland              Bern                3802
#  11                   Seeland              Bern                3077
#  12                Weinfelden           Thurgau                3197
#  13                    Lugano            Tessin                 NaN
#  14                   Yverdon             Waadt                 299
#  15             Pays-d’Enhaut             Waadt                2949
#  16                     Vevey             Waadt                 NaN
#  17                   Greyerz          Freiburg                 341
#  18                 Echallens             Waadt                 241
#  19                         —              Genf                  73
#  20                  Hochdorf            Luzern                2966
#  21                    Gösgen         Solothurn                   0
#  22                     Broye          Freiburg                 267
#  23                     Olten         Solothurn                 NaN
#  24                     Vevey          Freiburg                 410
#  25                  Dietikon            Zürich                   0
#  26               Kreuzlingen           Thurgau                 304
#  27                    Siders            Wallis                 280
#  28           Bern-Mittelland              Bern                   0
#  29           Bern-Mittelland              Bern                 NaN
#  ..                       ...               ...                 ...
#  43                   Yverdon             Waadt                 606
#  44                  Cossonay             Waadt                 696
#  45                   Greyerz          Freiburg                   0
#  46  Frutigen-Niedersimmental              Bern                 NaN
#  47            Westlich Raron            Wallis                 573
#  48                 Neuenburg         Neuenburg                 NaN
#  49                   Sissach  Basel-Landschaft                 405
#  50                      Oron             Waadt                1091
#  51                      Oron             Waadt                 312
#  52                Frauenfeld           Thurgau                1804
#  53                   Greyerz          Freiburg                 459
#  54                  Hochdorf            Luzern                 NaN
#  55                  Hochdorf            Luzern                6239
#  56                      Nyon             Waadt                1601
#  57                 Vivisbach          Freiburg                 829
#  58                  Grandson             Waadt                4333
#  59                         —               Zug                 NaN
#  60                       Wil        St. Gallen                 240
#  61                     Broye          Freiburg                 301
#  62                Münchwilen           Thurgau                 NaN
#  63                      Thun              Bern                1574
#  64                   Greyerz          Freiburg                 875
#  65                    Boudry         Neuenburg                 191
#  66                   Payerne             Waadt                 190
#  67                    Siders            Wallis                 451
#  68                   Greyerz          Freiburg                 260
#  69                See-Gaster        St. Gallen                1422
#  70  Frutigen-Niedersimmental              Bern                 NaN
#  71  Frutigen-Niedersimmental              Bern                2314
#  72                    Sursee            Luzern                4086
#
#  [73 rows x 5 columns],
#         0               1                    2  \
#  0   Rang   Agglomeration            Einwohner
#  1     1.          Zürich            1'369'041
#  2     2.            Genf  592'106 (857'309 *)
#  3     3.           Basel  547'761 (830'758 *)
#  4     4.        Lausanne              420'757
#  5     5.            Bern              418'225
#  6     6.          Luzern              229'407
#  7     7.      St. Gallen              166'762
#  8     8.          Lugano              151'207
#  9     9.      Winterthur              141'619
#  10   10.             Zug              130'668
#  11   11.     Baden-Brugg              110'693
#  12   12.        Freiburg              108'809
#  13   13.     Biel/Bienne              105'726
#  14   14.  Olten-Zofingen              100'866
#  15   15.       Neuenburg               89'769
#
#                                      3
#  0   Anzahl Gemeinden(inkl. Kernstadt)
#  1                                 150
#  2                                  88
#  3                                 107
#  4                                 127
#  5                                  73
#  6                                  19
#  7                                  23
#  8                                  51
#  9                                   8
#  10                                 14
#  11                                 15
#  12                                 31
#  13                                 26
#  14                                 21
#  15                                 17  ]

# %%
def citynames(elem):
    elem = elem.replace(" 1","").replace(" 2", "").replace(" / 3","")
    return elem
cities = list(t[0][1:][1].apply(citynames))

# %%
def einwohner(elem):
    #elem = elem.replace(" 1","").replace(" 2", "").replace(" / 3","")
    return elem
Einwohnerzahl = list(t[0][1:][6].apply(einwohner))

# %%
Einwohnerzahl
# Out:
# ["396'027",
#  "194'565",
#  "175'131",
#  "140'634",
#  "135'629",
#  "106'778",
#  "81'284",
#  "75'310",
#  "63'668",
#  "53'667",
#  "43'303",
#  "39'998",
#  "39'027",
#  "38'288",
#  "35'927",
#  "34'547",
#  "34'477",
#  "33'641",
#  "33'412",
#  "33'296",
#  "30'919",
#  "29'406",
#  "29'292",
#  "28'603",
#  "27'229",
#  "26'875",
#  "26'759",
#  "26'277",
#  "26'208",
#  "24'578",
#  "23'938",
#  "23'715",
#  "23'228",
#  "21'993",
#  "21'464",
#  "21'290",
#  "21'245",
#  "20'910",
#  "20'774",
#  "20'446",
#  "20'445",
#  "20'411",
#  "20'221",
#  "20'033",
#  "19'738",
#  "19'220",
#  "18'895",
#  "18'810",
#  "18'670",
#  "18'448",
#  "18'437",
#  "18'373",
#  "18'305",
#  "18'131",
#  "18'053",
#  "17'905",
#  "17'631",
#  "17'624",
#  "17'587",
#  "17'538",
#  "17'478",
#  "17'409",
#  "17'350",
#  "17'342",
#  "17'173",
#  "16'694",
#  "16'547",
#  "16'545",
#  "16'480",
#  "16'399",
#  "16'288",
#  "15'998",
#  "15'981",
#  "15'803",
#  "15'703",
#  "15'601",
#  "15'523",
#  "15'512",
#  "15'465",
#  "15'446",
#  "15'373",
#  "15'316",
#  "15'092",
#  "14'949",
#  "14'929",
#  "14'785",
#  "14'183",
#  "14'128",
#  "13'971",
#  "13'956",
#  "13'955",
#  "13'849",
#  "13'813",
#  "13'329",
#  "13'210",
#  "13'057",
#  "13'035",
#  "12'967",
#  "12'935",
#  "12'897",
#  "12'814",
#  "12'781",
#  "12'695",
#  "12'597",
#  "12'555",
#  "12'533",
#  "12'485",
#  "12'445",
#  "12'395",
#  "12'187",
#  "12'164",
#  "12'137",
#  "12'058",
#  "12'033",
#  "12'010",
#  "11'882",
#  "11'646",
#  "11'552",
#  "11'466",
#  "11'423",
#  "11'404",
#  "11'301",
#  "11'275",
#  "11'273",
#  "11'250",
#  "11'210",
#  "11'197",
#  "11'136",
#  "11'105",
#  "11'104",
#  "11'040",
#  "11'039",
#  "10'999",
#  "10'917",
#  "10'854",
#  "10'799",
#  "10'746",
#  "10'659",
#  "10'537",
#  "10'433",
#  "10'331",
#  "10'323",
#  "10'313",
#  "10'281",
#  "10'232",
#  "10'155",
#  "10'097",
#  "10'036"]

# %% [markdown]
# ## Jetzt ergänzen wir diese Städte

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=vietnamesische+restaurants+in+"
fields = "fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&"
locationbias = "locationbias=point:lat,lng&"
key = "key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&" # an den Key ein "&" anhängen
pagetoken = ''

for city in cities[:10]: #Nur die ersten Städte
    result = range(4) # der pagetoken ist an 4. Stelle der zurückgespielten Resultate
    while len(result) > 3: 
    
        print(len(result))
        api_query = url+query+city+"&"+fields+locationbias+key+pagetoken
        print(api_query)
        time.sleep(2)
        r = requests.get(api_query)
        result = r.json()
        print(len(result))
    
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
            lat = elem['geometry']['location']['lat']
            long = elem['geometry']['location']['lng']
    
            mini_dict = {'Addresse': address, 
                     'Name': name,
                     'Rating': rating,
                     'Lat':lat,
                     'Lng':long,
                     'City':city}
    
            new_list.append(mini_dict)
        
    
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token'] 
        else:
            pagetoken = ''
            break
# Out:
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Genf&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Basel&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Bern&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Lausanne&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Winterthur&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Luzern&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+St. Gallen&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CuQD2QEAAIh4i4WseRPntJKbHmJqdV8b8DyRznvCc_osMLxfvKZrF9DMdnWqKTc7Q1GQJcy136EYj37sLqGXjyA2t0ggMr-1rxEh0oaTzaiTR_BhP1VmwF7PzwD_Y52tDQpABYCxjKWIHhXbIhca-btf1mYlIE1h44Y523CXL3HNM3uzDgbOcY1Hb35FuhAI9X8G6LEEYL1iDWi-706L03rbjP_TLDOARsCFEgdIs8vb2xsw9IVCcjiPIwi7IfHGDPmSaiY0kPvdoAhJxjZFlOYic_iye6h95iQjGHmc2dgbHcX8_bnk07-unEsG3w2phQMff0aRCCp3iJposBVkmOd82RgliOuOCDO2JvvzWatZhTTe7mHttP1FFqE11b1sj-2Wakvf5pkExkzQMAfAs3_BenBRVXNbtppA2vlCU_m-LkjvjJ63Ix8jktiwaHdzBLK00AA0hYeI0a_evJhuDEko8stwfE8FmhUHis3WhUmDgaaCahkFwGT8ClA8fLsI5kq72K1Q2FaPwlOkdIxIWXX7GS-LWRpyTb2Kw52Rm__QnX-KqRAMqJmABPtPK7EfZD8uuZ3wMN0-Zs23zCEpx2a3n03Ff7vuGwl_7eK8mNA31PdFbS5n8P0gVi4CNF5XzwynVXVOwhIQGFcbk-nT0odbg3ume9kjLhoU1410oLw94R1nTLO_2jJGw3QR5Bg
# 4
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&pagetoken=CoQFeQIAAHftXygfk3aLPYe4Jz60KTb09Qj2jvCdAyanLKEAqgKlITia6R6YO_oQ2Lx3Pknh01XftipXx3Q67IMstoNxxbZ4QbAe_cTikVpcP03fcRwNeuMJ-5_h7rf3nJbQvf3B2wWVD2ZjUvJsOUqoaso7_GHDxK9mStIfa_1vB2rYEaYVo15iDbmADy6esGFwIsjIbP9vQuMbHBVr3iho_4N01IjkD9dm7oFnE_OZJl7ccFOe9434rE1bj_72Xkzy2VM4IQ5MGAs14GJurFq2ohb3TjSDffhAS-Jdejx3eDjt4c1_jU_kWO3LDcSXjnThH8Zrk5dF78b8lxoyeMGrEY7A-Ckih5bBAEDu4VnUo3YfdkroCsiz0dwcMz5Q1NRmhc0TwpfthTQSizVEdt7EPbhgCLBZWhnGWbK7IEw6TAhxPRhkm3lngDGwnzR7LelGLYLCswjTyEt1eBwOTjNbEtkRfVGDSOuIwrgvBC1j0LJVhivnormzQqr5GCcgvrPj94UzlCN9JucERzaz8e2gpzcTsVJe53XCEIf3z1tiBos6guB5jp3Ppi-O-KGQIwZhjqcak8jheDAQ7hjXeahpVg-NZaZecPDZEydKtTC3z1rzZlc7GNn9GIf3u8CAe1UelKLZHmmqDCJT05wkO37cfquMPb1FfxzEKy4IBXTOmLqbK_zm2NRVTRIsrNAzccNuN6E4JXg6E6Uv9Z87991b97wU7dY5LAXWvzoRTs43HMseecZTO_359JZCORZdkxszOW3l79qH3VsUxuuGrIuZCdLrEjSeXA5MID1IEtTLlLGh00rL2c1GA8UImkecu2FQFCM2DjySy75CDeRpwbqOG-F7gMISEL60eyZpSjDfuChOs_3bqlAaFHwDyPzWG2aMW8gDBLcQ2fJMm_t6
# 3
# 4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=vietnamesische+restaurants+in+Biel/Bienne&fields=formatted_address,name,rating,opening_hours,price_level,pagetoken&locationbias=point:lat,lng&key=AIzaSyDTGVudHI8hCSyUm5GNH8yLxdzqlkiHey4&
# 3

# %%
df = pd.DataFrame(new_list) # erst hier definiere ich den df

# %%
cityliste = list(df['City'])

# %%
df
# Out:
#                                               Addresse         City  \
# 0        Uetlibergstrasse 77, 8045 Zürich, Switzerland       Zürich
# 1             Langstrasse 13, 8004 Zürich, Switzerland       Zürich
# 2         Gasometerstrasse 7, 8005 Zürich, Switzerland       Zürich
# 3             Sihlstrasse 97, 8001 Zürich, Switzerland       Zürich
# 4        Zypressenstrasse 50, 8004 Zürich, Switzerland       Zürich
# 5           Kehlhofstrasse 4, 8003 Zürich, Switzerland       Zürich
# 6    Schwamendingenstrasse 10, 8050 Zürich, Switzer...       Zürich
# 7    Schaffhauserstrasse 127, 8057 Zürich, Switzerland       Zürich
# 8    Schaffhauserstrasse 475, 8052 Zürich, Switzerland       Zürich
# 9            Josefstrasse 42, 8005 Zürich, Switzerland       Zürich
# 10   Birmensdorferstrasse 126, 8003 Zürich, Switzer...       Zürich
# 11           Rolandstrasse 9, 8004 Zürich, Switzerland       Zürich
# 12   Leutschenbachstrasse 71, 8050 Zürich, Switzerland       Zürich
# 13   Schaffhauserstrasse 127, 8057 Zürich, Switzerland       Zürich
# 14           Kanonengasse 31, 8004 Zürich, Switzerland       Zürich
# 15          Bülachstrasse 25, 8057 Zürich, Switzerland       Zürich
# 16         Militärstrasse 84, 8004 Zürich, Switzerland       Zürich
# 17          Rue de Zurich 43, 1201 Genève, Switzerland         Genf
# 18     Rue de la Servette 20, 1201 Genève, Switzerland         Genf
# 19         Rue de Carouge 73, 1205 Genève, Switzerland         Genf
# 20   Boulevard de Saint-Georges 71, 1205 Genève, Sw...         Genf
# 21   Boulevard de la Cluse 105, 1205 Genève, Switze...         Genf
# 22   Boulevard de Saint-Georges 68, 1205 Genève, Sw...         Genf
# 23    Rue Adhémar-Fabri 8-10, 1201 Genève, Switzerland         Genf
# 20      4.1
# 21      4.1
# 22      4.4
# 23      4.7
# 24      4.2
# 25      4.2
# 26      4.5
# 27      4.6
# 28      4.6
# 29      4.5
# ..      ...
# 80      3.6
# 81      4.3
# 82      4.1
# 83      4.1
# 84      4.4
# 85      4.4
# 86      4.2
# 87      4.5
# 88      4.2
# 89      4.4
# 90      4.1
# 91      4.1
# 92      4.4
# 93      4.1
# 94      4.1
# 95      4.1
# 96      4.5
# 97      4.1
# 98      2.9
# 99      3.9
# 100     4.1
# 101     4.2
# 102     3.5
# 103     4.2
# 104     4.4
# 105     4.2
# 106     4.3
# 107     4.1
# 108     4.4
# 109     3.7
#
# [110 rows x 6 columns]

# %%
addressenliste = list(df['Addresse'])

# %%
checkedlist = []
for city, address in zip(cityliste,addressenliste):
    if city in address:
        checkedlist.append(True)
    else:
        checkedlist.append(False)

# %%
df = pd.DataFrame(new_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 6 columns):
# Addresse    110 non-null object
# City        110 non-null object
# Lat         110 non-null float64
# Lng         110 non-null float64
# Name        110 non-null object
# Rating      110 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 5.2+ KB

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 0 to 109
# Data columns (total 6 columns):
# Addresse    110 non-null object
# City        110 non-null object
# Lat         110 non-null float64
# Lng         110 non-null float64
# Name        110 non-null object
# Rating      110 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 6.0+ KB

# %%
df.to_csv('vietnamrest_allcities.csv')

# %%
pd.DataFrame(df)
df
# Out:
#                                               Addresse         City  \
# 0        Uetlibergstrasse 77, 8045 Zürich, Switzerland       Zürich
# 1             Langstrasse 13, 8004 Zürich, Switzerland       Zürich
# 2         Gasometerstrasse 7, 8005 Zürich, Switzerland       Zürich
# 3             Sihlstrasse 97, 8001 Zürich, Switzerland       Zürich
# 4        Zypressenstrasse 50, 8004 Zürich, Switzerland       Zürich
# 5           Kehlhofstrasse 4, 8003 Zürich, Switzerland       Zürich
# 6    Schwamendingenstrasse 10, 8050 Zürich, Switzer...       Zürich
# 7    Schaffhauserstrasse 127, 8057 Zürich, Switzerland       Zürich
# 8    Schaffhauserstrasse 475, 8052 Zürich, Switzerland       Zürich
# 9            Josefstrasse 42, 8005 Zürich, Switzerland       Zürich
# 10   Birmensdorferstrasse 126, 8003 Zürich, Switzer...       Zürich
# 11           Rolandstrasse 9, 8004 Zürich, Switzerland       Zürich
# 12   Leutschenbachstrasse 71, 8050 Zürich, Switzerland       Zürich
# 13   Schaffhauserstrasse 127, 8057 Zürich, Switzerland       Zürich
# 14           Kanonengasse 31, 8004 Zürich, Switzerland       Zürich
# 15          Bülachstrasse 25, 8057 Zürich, Switzerland       Zürich
# 16         Militärstrasse 84, 8004 Zürich, Switzerland       Zürich
# 17          Rue de Zurich 43, 1201 Genève, Switzerland         Genf
# 18     Rue de la Servette 20, 1201 Genève, Switzerland         Genf
# 19         Rue de Carouge 73, 1205 Genève, Switzerland         Genf
# 20   Boulevard de Saint-Georges 71, 1205 Genève, Sw...         Genf
# 21   Boulevard de la Cluse 105, 1205 Genève, Switze...         Genf
# 22   Boulevard de Saint-Georges 68, 1205 Genève, Sw...         Genf
# 13      4.3
# 14      4.5
# 15      4.6
# 16      4.6
# 17      3.7
# 18      3.9
# 19      4.3
# 20      4.1
# 21      4.1
# 22      4.4
# 23      4.7
# 24      4.2
# 25      4.2
# 26      4.5
# 27      4.6
# 28      4.6
# 29      4.5
# ..      ...
# 80      3.6
# 81      4.3
# 82      4.1
# 83      4.1
# 84      4.4
# 85      4.4
# 86      4.2
# 87      4.5
# 88      4.2
# 89      4.4
# 90      4.1
# 91      4.1
# 92      4.4
# 93      4.1
# 94      4.1
# 95      4.1
# 96      4.5
# 97      4.1
# 98      2.9
# 99      3.9
# 100     4.1
# 101     4.2
# 102     3.5
# 103     4.2
# 104     4.4
# 105     4.2
# 106     4.3
# 107     4.1
# 108     4.4
# 109     3.7
#
# [110 rows x 6 columns]

# %%
df["Stadt"] = df["Addresse"]
df["Stadt"]
# Out:
# 0          Uetlibergstrasse 77, 8045 Zürich, Switzerland
# 1               Langstrasse 13, 8004 Zürich, Switzerland
# 2           Gasometerstrasse 7, 8005 Zürich, Switzerland
# 3               Sihlstrasse 97, 8001 Zürich, Switzerland
# 4          Zypressenstrasse 50, 8004 Zürich, Switzerland
# 5             Kehlhofstrasse 4, 8003 Zürich, Switzerland
# 6      Schwamendingenstrasse 10, 8050 Zürich, Switzer...
# 7      Schaffhauserstrasse 127, 8057 Zürich, Switzerland
# 8      Schaffhauserstrasse 475, 8052 Zürich, Switzerland
# 9              Josefstrasse 42, 8005 Zürich, Switzerland
# 10     Birmensdorferstrasse 126, 8003 Zürich, Switzer...
# 11             Rolandstrasse 9, 8004 Zürich, Switzerland
# 12     Leutschenbachstrasse 71, 8050 Zürich, Switzerland
# 13     Schaffhauserstrasse 127, 8057 Zürich, Switzerland
# 14             Kanonengasse 31, 8004 Zürich, Switzerland
# 15            Bülachstrasse 25, 8057 Zürich, Switzerland
# 16           Militärstrasse 84, 8004 Zürich, Switzerland
# 17            Rue de Zurich 43, 1201 Genève, Switzerland
# 18       Rue de la Servette 20, 1201 Genève, Switzerland
# 19           Rue de Carouge 73, 1205 Genève, Switzerland
# 20     Boulevard de Saint-Georges 71, 1205 Genève, Sw...
# 21     Boulevard de la Cluse 105, 1205 Genève, Switze...
# 22     Boulevard de Saint-Georges 68, 1205 Genève, Sw...
# 23      Rue Adhémar-Fabri 8-10, 1201 Genève, Switzerland
# 24          Rue du Cendrier 10, 1201 Genève, Switzerland
# 25       Quai du Mont-Blanc 13, 1201 Genève, Switzerland
# 26        45 Margarethenstrasse Basel, 4053, Switzerland
# 27          Friedrichstrasse 25, 4055 Basel, Switzerland
# 28           Kapellenstrasse 37, 4052 Basel, Switzerland
# 29         Bruderholzstrasse 39, 4053 Basel, Switzerland
#                              ...
# 80      piazza della riforma 1, 6900 Lugano, Switzerland
# 81               Via Cantonale, 6912 Lugano, Switzerland
# 82        Via Giuseppe Motta 7, 6900 Lugano, Switzerland
# 83          8, Piazza Cioccaro, 6900 Lugano, Switzerland
# 84     Viale Carlo Cattaneo 21, 6900 Lugano, Switzerland
# 85             Via Ronchetto 6, 6900 Lugano, Switzerland
# 86                  Via Foce 9, 6900 Lugano, Switzerland
# 87       Via Antonio Fusoni 18, 6900 Lugano, Switzerland
# 88           Via della Posta 4, 6900 Lugano, Switzerland
# 89     Via ai Canvetti 15, 6926 Montagnola, Collina d...
# 90                Via Zurigo 6, 6900 Lugano, Switzerland
# 91            Piazza Riforma 9, 6900 Lugano, Switzerland
# 92        Via Luigi Canonica 5, 6900 Lugano, Switzerland
# 93       Piazza Indipendenza 4, 6900 Lugano, Switzerland
# 94      Piazza Alighieri Dante, 6901 Lugano, Switzerland
# 95     Via Clemente Maraini 12, 6900 Lugano, Switzerland
# 96               Via Ginevra 4, 6900 Lugano, Switzerland
# 97            Piazza Riforma 9, 6900 Lugano, Switzerland
# 98            Piazza Riforma 1, 6900 Lugano, Switzerland
# 99     Viale Carlo Cattaneo 25, 6900 Lugano, Switzerland
# 100      Via Ferruccio Pelli 7, 6900 Lugano, Switzerland
# 101    Corso Enrico Pestalozzi 12, 6900 Lugano, Switz...
# 102    Piazza Riziero Rezzonico 2, 6900 Lugano, Switz...
# 103              3, Via Zurigo, 6900 Lugano, Switzerland
# 104        Via del Tiglio 13/A, 6900 Lugano, Switzerland
# 105    Corso Enrico Pestalozzi 27, 6900 Lugano, Switz...
# 106           Corso Elvezia 22, 6900 Lugano, Switzerland
# 107          Piazzale Stazione, 6900 Lugano, Switzerland
# 108            Via Moncucco 35, 6900 Lugano, Switzerland
# 109              Pianostrasse 48, 2503 Biel, Switzerland
# Name: Stadt, Length: 110, dtype: object

# %%
#geht leider nicht
new_df = pd.DataFrame(df["Addresse"].str.split(', ').tolist(),
                                   columns = ['strasse', 'stadt', 'land'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-32-0690a4fcadb3> in <module>()
#       1 new_df = pd.DataFrame(df["Addresse"].str.split(', ').tolist(),
# ----> 2                                    columns = ['strasse', 'stadt', 'land'])
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    7473     if isinstance(data[0], (list, tuple)):
#    7474         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# -> 7475                                dtype=dtype)
#    7476     elif isinstance(data[0], collections.Mapping):
#    7477         return _list_of_dict_to_arrays(data, columns,
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/frame.py in _list_to_arrays(data, columns, coerce_float, dtype)
#    7552         content = list(lib.to_object_array(data).T)
#    7553     return _convert_object_array(content, columns, dtype=dtype,
# -> 7554                                  coerce_float=coerce_float)
#    7555
#    7556
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/pandas/core/frame.py in _convert_object_array(content, columns, coerce_float, dtype)
#    7610             raise AssertionError('{col:d} columns passed, passed data had '
#    7611                                  '{con} columns'.format(col=len(columns),
# -> 7612                                                         con=len(content)))
#    7613
#    7614     # provide soft conversion of object dtypes
#
# AssertionError: 3 columns passed, passed data had 4 columns

# %%
df
