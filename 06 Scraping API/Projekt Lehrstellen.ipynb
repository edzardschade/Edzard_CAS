# %% [markdown]
# Projekt Lehrstellen pro Beruf und Betrieb

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
r = requests.get("https://www.berufsberatung.ch/dyn/show/2930")
soup = BeautifulSoup(r.text, 'html.parser')

# %%
#mit requests. können wir pdfs öffnen.

# %%
soup.find_all('li')[8]
# Out:
# <li>
# <a class="page_2086" href="/dyn/show/2086">Suche</a>
# </li>

# %%
#Hier wird die ganze Auswahl auf den ul tag mit class ui autocomplete full list ein.
soup = soup.find_all('ul', {'class': 'ui-autocomplete full-list '})

# %%
soup
# Out:
# [<ul class="ui-autocomplete full-list ">
# ...

# %%
soup.find_all('li')[1:][0].find('a')['id']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-90b274c67986> in <module>()
# ----> 1 soup.find_all('li')[1:][0].find('a')['id']
#
# ~/.virtualenvs/erstesVE/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
#wie weiter: Liste mit Veranstaltern und mit den links auf die Unterseite mit pdf machen
