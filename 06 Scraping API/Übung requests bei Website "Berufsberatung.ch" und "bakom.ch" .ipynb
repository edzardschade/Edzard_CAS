# %%
# !pip install bs4
# !pip install pandas
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
r = requests.get('https://www.berufsberatung.ch')
r = r.text #variable r als r.text definiert.

# %%
soup = BeautifulSoup(r, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 7]> 				 <html class="no-js ie7 mobileVersion" lang="de"> <![endif]-->
# <!--[if IE 8]> 				 <html class="no-js mobileVersion lt-ie9" lang="de"> <![endif]-->
# <!--[if IE 9]>			 		<html class="no-js mobileVersion ie9" lang="de"> <![endif]-->
# <!--[if gt IE 8]>			 <html class="no-js mobileVersion" lang="de"> <![endif]-->
# <html class="mobileVersion" lang="de">
# <head>
# <meta charset="utf-8"/>
# <meta content="SDBB | CSFO" name="publisher"/>
# <meta content="global" name="distribution"/>
# <meta content="SDBB | CSFO" name="author"/>
# <meta content="SDBB | CSFO" name="copyright"/>
# <meta content="general" name="rating"/>
# <meta content="de" name="language">
# <meta content="width=device-width, initial-scale=1" id="viewport" name="viewport"/>
# <meta content="include" name="cludocrawler"/>
# <title>Homepage - berufsberatung.ch</title>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# ...

# %%
soup.find_all('a')
elementlist = soup.find_all('a')

# %%
elementlist
# Out:
# []

# %%
len(soup.find_all('a'))
#schauen, wieviele Elemente es gibt.
# Out:
# 455

# %%
#Suchen, ab welchem Element sich tatsächlich die Titel befinden.
lst = elementlist[0:][:200]

# %%
lst[100]
# Out:
# <a class="page_6697" href="/dyn/show/6697">Zulassung PH</a>

# %% [markdown]
# Hier schaue ich von der Website Bakom.admin.ch die Unterseite "Radio lokal/regional" an
#
# https://www.bakom.admin.ch/bakom/de/home/elektronische-medien/informationen-ueber-radio-und-fernsehveranstalter/radio-lokal-regional.html

# %%
r = requests.get('https://www.bakom.admin.ch/bakom/de/home/elektronische-medien/informationen-ueber-radio-und-fernsehveranstalter/radio-lokal-regional.html')
r = r.text #variable r als r.text definiert.

# %%
r
# Out:
# '\n\n\n\n<!DOCTYPE HTML>\n<!--[if lt IE 7 ]> <html lang="de" class="no-js ie6 oldie"> <![endif]-->\n<!--[if IE 7 ]> <html lang="de" class="no-js ie7 oldie"> <![endif]-->\n<!--[if IE 8 ]> <html lang="de" class="no-js ie8 oldie"> <![endif]-->\n<!--[if IE 9 ]> <html lang="de" class="no-js ie9"> <![endif]-->\n<!--[if gt IE 9 ]><!--><html lang="de" class="no-js no-ie"> <!--<![endif]-->\n\n\n    \n\r\n<head>\r\n    \r\n    \n\n\n\n\t\n\t\n\t\t<title>Radio lokal/regional</title>\n\t\n\t\n\n\n<meta charset="utf-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n<meta http-equiv="cleartype" content="on" />\n\n\n\t<meta name="msapplication-TileColor" content="#ffffff"/>\n\t<meta name="msapplication-TileImage" content="/etc/designs/core/frontend/guidelines/img/ico/mstile-144x144.png"/>\n\t<meta name="msapplication-config" content="/etc/designs/core/frontend/guidelines/img/ico/browserconfig.xml"/>\n\n\n\n\t\n\
# ...

# %%
soup = BeautifulSoup(r, "html.parser")
soup
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html lang="de" class="no-js ie6 oldie"> <![endif]-->
# <!--[if IE 7 ]> <html lang="de" class="no-js ie7 oldie"> <![endif]-->
# <!--[if IE 8 ]> <html lang="de" class="no-js ie8 oldie"> <![endif]-->
# <!--[if IE 9 ]> <html lang="de" class="no-js ie9"> <![endif]-->
# <!--[if gt IE 9 ]><!--><html class="no-js no-ie" lang="de"> <!--<![endif]-->
# <head>
# <title>Radio lokal/regional</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/etc/designs/core/frontend/guidelines/img/ico/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="/etc/designs/core/frontend/guidelines/img/ico/browserconfig.xml" name="msapplication-config"/>
# <meta content="de" name="language"/>
# ...

# %%
soup.find_all('div')
len(soup.find_all('div'))
#schauen, wieviele Elemente es gibt.
# Out:
# 118

# %%
elementlist = soup.find_all('div')
elementlist
# Out:
# [<div class="mod mod-contentpagewide">
#  <ul class="access-keys" role="navigation">
#  <li><a accesskey="0" href="/bakom/de/home.html">Homepage</a></li>
#  <li><a accesskey="1" href="#main-navigation">Main navigation</a></li>
#  <li><a accesskey="2" href="#content">Content area</a></li>
#  <li><a accesskey="3" href="#site-map">Sitemap</a></li>
#  <li><a accesskey="4" href="#search-field">Search</a></li>
#  </ul>
#  </div>, <div class="container container-main">
#  <header role="banner" style="background-size: cover; background-image:">
#  <div class="clearfix">
#  <nav class="navbar treecrumb pull-left">
#  <h2 class="sr-only">Treecrumb Bundesverwaltung</h2>
#  <ul class="nav navbar-nav">
#  <li class="dropdown">
#  <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="federalAdministration-dropdown"><span class="icon icon--right"></span> Der Bundesrat</a>
#  <ul aria-labelledby="federalAdministration-dropdown" class="dropdown-menu" role="menu">
# ...

# %%
#Suchen, ab welchem Element sich tatsächlich die Titel befinden.
#das untere Beispiel zeit, wie ich den Range einstellen kann. Ist hier noch nicht wichtig.
lst = elementlist[0:][:118]

# %%
lst[90]
# Out:
# <div class="mod mod-contactbox">
# </div>
