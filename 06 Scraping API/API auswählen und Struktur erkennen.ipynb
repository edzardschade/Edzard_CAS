# %%
import requests

# %%
requests.get("https://opendata.swiss/api/3/action/package_show?id=strukturelle-analyse-der-schweizer-wirtschaft")
# Out:
# <Response [200]>

# %%
wirtschaftsdaten = requests.get("https://opendata.swiss/api/3/action/package_show?id=strukturelle-analyse-der-schweizer-wirtschaft")

# %%
wirtschaftsdaten
# Out:
# <Response [200]>

# %%
wirtschaftsdaten.json()
# Out:
# {'help': 'https://opendata.swiss/api/3/action/help_show?name=package_show',
#  'success': True,
#  'result': {'license_title': None,
#   'maintainer': 'info@bfs.admin.ch',
#   'issued': '2008-05-23T02:00:00',
#   'private': False,
#   'maintainer_email': 'auskunftsdienst@bfs.admin.ch',
#   'num_tags': 16,
#   'contact_points': [{'email': 'auskunftsdienst@bfs.admin.ch',
#     'name': 'info@bfs.admin.ch'}],
#   'keywords': {'rm': ['economia-publica'],
#    'fr': ['comptabilite-nationale',
#     'publication',
#     'statistique-de-synthese',
#     'economie-nationale'],
#    'de': ['publikation',
#     'volkswirtschaftliche-gesamtrechnung',
#     'volkswirtschaft',
#     'synthesestatistik'],
#    'en': ['national-economy',
#     'publication',
#     'summary-statistics',
#     'national-accounts'],
#    'it': ['statistica-di-sintesi',
#     'contabilita-nazionale',
#     'economia-nazionale',
#     'pubblicazione']},
#   'temporals': [{'start_date': '1991-01-01T01:00:00',
# ...

# %%
wirtschaftsdaten = wirtschaftsdaten.json()

# %%
wirtschaftsdaten.keys()
# Out:
# dict_keys(['help', 'success', 'result'])

# %%
wirtschaftsdaten['result'].keys() 
#bei dictionarys werden die keys immer mit [] aufgerufen..
# Out:
# dict_keys(['license_title', 'maintainer', 'issued', 'private', 'maintainer_email', 'num_tags', 'contact_points', 'keywords', 'temporals', 'id', 'metadata_created', 'relationships_as_object', 'display_name', 'metadata_modified', 'author', 'author_email', 'relations', 'state', 'version', 'spatial', 'license_id', 'type', 'resources', 'publishers', 'num_resources', 'description', 'tags', 'title', 'language', 'groups', 'creator_user_id', 'relationships_as_subject', 'organization', 'name', 'isopen', 'url', 'owner_org', 'extras', 'see_alsos', 'revision_id', 'identifier'])
